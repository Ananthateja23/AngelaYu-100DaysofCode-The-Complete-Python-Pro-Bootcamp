# %% [markdown]
# ## **Namespaces: Local vs Global Scope**
# ```python
# Local Scope:
#
# Variables (or functions) declared inside functions have local scope (also called function scope).
# They are only seen by other code within the same block of code.
#
# e.g.
#
# def my_function():
#     my_local_var = 2
#
# # This will cause a NameErrorr
# print(my_local_var)
#
# Global Scope:
#
# Variables or functions declared at the top level (unindented) of a code file have global scope.
# It is accessible anywhere in the code file.
#
# e.g.
#
# my_global_var = 3
#
# def my_function():
#     # This works no problems
#     print(my_global_var)
# ```

# %%
enemies = 1


def increase_enemies():
    enemies = 2
    print(f"enemies inside function: {enemies}")


increase_enemies()
print(f"enemies outside function: {enemies}")
# Out:
# enemies inside function: 2
# enemies outside function: 1

# %%
# Local scope

def drink_potion():
    potion_strength = 2
    print(potion_strength)

drink_potion()
# Out:
# 2

# %%
def drink_potion():
    potion_strength = 2
    print(potion_strength) # Inside the function

drink_potion()
print(potion_strength) # outside the function
# Out:
# 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       3     print(potion_strength) # Inside the function
#       5 drink_potion()
# ----> 6 print(potion_strength) # outside the function
#
# NameError: name 'potion_strength' is not defined

# %%
# Global scope

player_health = 10

def drink_potion():
    print("Inside drink potion fun")
    print(player_health)

drink_potion()
print(player_health)
# Out:
# Inside drink potion fun
# 10
# 10

# %%
player_health = 10

def gamer():
    print("Inside gamer function")
    def drink_potion():
        print("Inside drink potion fun")
        print(player_health)

    drink_potion()
gamer()
print(player_health)
# Out:
# Inside gamer function
# Inside drink potion fun
# 10
# 10

# %% [markdown]
# ## **Block Scope**
# ```
# Python is a bit different from other programming languages in that it does not have block scope.
#
# This means that variables created nested in other blocks of code e.g. for loops, if statements, while loops etc. don't get local scope. They are given function scope if they are within a function or global scope if they are not.
#
# e.g.
#
# # Accessible anywhere
# my_global_var = 1
#
# def my_function():
#     # Only accessible within my_function()
#     my_local_var = 2
#
# for _ in range(10):
#     # Accessible anywhere
#     my_block_var = 3
#
# ```

# %%
game_level = 3
enemies = ["Skeleton", "Zombie", "Alien"]

if game_level < 10:
    new_enemy = enemies[0]
    
print(new_enemy)
# Out:
# Skeleton

# %%
game_level = 3
enemies = ["Skeleton", "Zombie", "Alien"]

def create_enemy():
    if game_level < 10:
        new_enemi = enemies[0]
    
print(new_enemi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 8
#       5     if game_level < 10:
#       6         new_enemi = enemies[0]
# ----> 8 print(new_enemi)
#
# NameError: name 'new_enemi' is not defined

# %%
game_level = 3
enemies = ["Skeleton", "Zombie", "Alien"]

def create_enemy():
    print("Inside function")
    if game_level < 10:
        new_enemi = enemies[0]
    
    print(new_enemi)

create_enemy()
# Out:
# Inside function
# Skeleton

# %%
game_level = 10
enemies = ["Skeleton", "Zombie", "Alien"]

def create_enemy():
    print("Inside function")
    if game_level < 5:
        new_enemie = enemies[0]
    
    print(new_enemie)

create_enemy()
# Out:
# Inside function
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[15], line 11
#       7         new_enemie = enemies[0]
#       9     print(new_enemie)
# ---> 11 create_enemy()
#
# Cell In[15], line 9, in create_enemy()
#       6 if game_level < 5:
#       7     new_enemie = enemies[0]
# ----> 9 print(new_enemie)
#
# UnboundLocalError: cannot access local variable 'new_enemie' where it is not associated with a value

# %%
game_level = 10
enemies = ["Skeleton", "Zombie", "Alien"]

def create_enemy():
    print("Inside function")
    new_enemie = ""
    if game_level < 5:
        new_enemie = enemies[0]
    
    print(new_enemie)

create_enemy()
# Out:
# Inside function

# %% [markdown]
# ## **Coding Exercise**
# ```
# Prime Number Checker:
#
# Prime numbers are numbers that can only be cleanly divided by themselves and 1.
#
# Wikipedia : https://en.wikipedia.org/wiki/Prime_number
#
# You need to write a function called is_prime() that checks whether if the number passed into it is a prime number or not.  It should return True or False.
#
# e.g.
#
# 7 is a primer number because it is only divisible by 1 and itself.
#
# But 4 is not a prime number because you can divide it by 1, 2 or 4.
#
# NOTE:
#
# 2 is a prime number because it's only divisible by 1 and itself, but 1 is not a prime number because it is only divisible by 1.
#
# Example Input 1: 73
#
# Example Output 1: True
#
#
#
# Example Input 2: 75
#
# Example Output 2: False
# ```

# %%
def is_prime(num):
    if num <= 1:
        return False
    for i in range(2, num//2 + 1):
        if (num % i == 0):
            return False
    return True

# %%
print(is_prime(1))
print(is_prime(2))
print(is_prime(73))
print(is_prime(75))
# Out:
# False
# True
# True
# False

# %% [markdown]
# ## **How to modify a Global Variable**
# ```python
# You can force the code allow you to modify something with global if you use the global keyword before you use it.
#
# e.g. This will give you an error
#
# a = 1
# def my_function():
#     a += 1
#     print(a)
#
# But this will work
#
# a = 1
# def my_function():
#     global a
#     a += 1
#     print(a)
# ```

# %%
# Modifying Global Scope

enemies = 1


def increase_enemies():
    enemies = 2
    print(f"enemies inside function: {enemies}")


increase_enemies()
print(f"enemies outside function: {enemies}")
# Out:
# enemies inside function: 2
# enemies outside function: 1

# %%
# Modifying Global Scope

enemies = 1


def increase_enemies():
    enemies += 1
    print(f"enemies inside function: {enemies}")


increase_enemies()
print(f"enemies outside function: {enemies}")
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[18], line 11
#       7     enemies += 1
#       8     print(f"enemies inside function: {enemies}")
# ---> 11 increase_enemies()
#      12 print(f"enemies outside function: {enemies}")
#
# Cell In[18], line 7, in increase_enemies()
#       6 def increase_enemies():
# ----> 7     enemies += 1
#       8     print(f"enemies inside function: {enemies}")
#
# UnboundLocalError: cannot access local variable 'enemies' where it is not associated with a value

# %%
# Modifying Global Scope

enemies = 1


def increase_enemies():
    enemies = 0
    enemies += 1
    print(f"enemies inside function: {enemies}")


increase_enemies()
print(f"enemies outside function: {enemies}")
# Out:
# enemies inside function: 1
# enemies outside function: 1

# %%
# Modifying Global Scope

enemies = 1


def increase_enemies():
    global enemies
    enemies += 1
    print(f"enemies inside function: {enemies}")


increase_enemies()
print(f"enemies outside function: {enemies}")
# Out:
# enemies inside function: 2
# enemies outside function: 2

# %%
# Modifying Global Scope

enemies = 1


def increase_enemies(enemy):
    print(f"enemies inside function: {enemies}")
    return enemy + 1


enemies = increase_enemies(enemies)
print(f"enemies outside function: {enemies}")
# Out:
# enemies inside function: 1
# enemies outside function: 2

# %% [markdown]
# ## **Python Constants and Global Scope**
# ```
# You can define global constants in your code file for easy access. Their job is meant to be "set and forget" so you can use their values but never need to mofy them.
#
# Naming Convention
# Global constants are normally declared in ALL_CAPS with a underscore in between.
#
# e.g.
#
# PI = 3.14159
# GOOGLE_URL = "https://www.google.com"
# ```

# %%
# Global constants

PI = 3.14159
GOOGLE_URL = "https://www.google.com"

# function
def my_function():
    print(PI)
    print(GOOGLE_URL)

my_function()
# Out:
# 3.14159
# https://www.google.com

# %% [markdown]
# ## **Day12: Number Guessing**

# %%
import random
logo = r"""
  / _ \_   _  ___  ___ ___  /__   \ |__   ___    /\ \ \_   _ _ __ ___ | |__   ___ _ __ 
 / /_\/ | | |/ _ \/ __/ __|   / /\/ '_ \ / _ \  /  \/ / | | | '_ ` _ \| '_ \ / _ \ '__|
/ /_\\| |_| |  __/\__ \__ \  / /  | | | |  __/ / /\  /| |_| | | | | | | |_) |  __/ |   
\____/ \__,_|\___||___/___/  \/   |_| |_|\___| \_\ \/  \__,_|_| |_| |_|_.__/ \___|_| 
"""

# %%
from random import randint
# from art import logo


EASY_LEVEL_TURNS = 10
HARD_LEVEL_TURNS = 5


# Function to check users' guess against actual answer
def check_answer(user_guess, actual_answer, turns):
    """Checks answer against guess, returns the number of turns remaining."""
    if user_guess > actual_answer:
        print("Too high.")
        return turns - 1
    elif user_guess < actual_answer:
        print("Too low.")
        return turns - 1
    else:
        print(f"You got it! The answer was {actual_answer}")


# Function to set difficulty
def set_difficulty():
    level = input("Choose a difficulty. Type 'easy' or 'hard': ")
    if level == "easy":
        return EASY_LEVEL_TURNS
    else:
        return HARD_LEVEL_TURNS


def game():
    print(logo)
    # Choosing a random number between 1 and 100.
    print("Welcome to the Number Guessing Game!")
    print("I'm thinking of a number between 1 and 100.")
    answer = randint(1, 100)
    print(f"Pssst, the correct answer is {answer}")

    turns = set_difficulty()

    # Repeat the guessing functionality if they get it wrong.
    guess = 0
    while guess != answer:
        print(f"You have {turns} attempts remaining to guess the number.")
        # Let the user guess a number
        guess = int(input("Make a guess: "))
        # Track the number of turns and reduce by 1 if they get it wrong
        turns = check_answer(guess, answer, turns)
        if turns == 0:
            print("You've run out of guesses, you lose.")
            return
        elif guess != answer:
            print("Guess again.")




game()
# Out:
#   / _ \_   _  ___  ___ ___  /__   \ |__   ___    /\ \ \_   _ _ __ ___ | |__   ___ _ __
#  / /_\/ | | |/ _ \/ __/ __|   / /\/ '_ \ / _ \  /  \/ / | | | '_ ` _ \| '_ \ / _ \ '__|
# / /_\\| |_| |  __/\__ \__ \  / /  | | | |  __/ / /\  /| |_| | | | | | | |_) |  __/ |
# \____/ \__,_|\___||___/___/  \/   |_| |_|\___| \_\ \/  \__,_|_| |_| |_|_.__/ \___|_|
#
# Welcome to the Number Guessing Game!
# I'm thinking of a number between 1 and 100.
# Pssst, the correct answer is 73
# Choose a difficulty. Type 'easy' or 'hard':  hard
# You have 5 attempts remaining to guess the number.
# Make a guess:  50
# Too low.
# Guess again.
# You have 4 attempts remaining to guess the number.
# Make a guess:  80
# Too high.
# Guess again.
# You have 3 attempts remaining to guess the number.
# Make a guess:  70
# Too low.
# Guess again.
# You have 2 attempts remaining to guess the number.
# Make a guess:  75
# Too high.
# Guess again.
# You have 1 attempts remaining to guess the number.
# Make a guess:  73
# You got it! The answer was 73
