# %% [markdown]
# ## **Python Primitive Data Types**

# %%
print(len("hello"))
# Out:
# 5

# %%
print(len(123456))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(len(123456))
#
# TypeError: object of type 'int' has no len()

# %% [markdown]
# - String
# - Integer
# - Float
# - Boolean

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# - Note:
# - The method of pulling out a particular element from a string is called `subscripting`

# %%
print("Hello"[0])
# Out:
# H

# %%
print("Hello"[4])
# Out:
# o

# %%
print("Hello"[-1])
# Out:
# o

# %%
# String

print("123" + "345")
# Out:
# 123345

# %%
# Integer: Numbers without any decimal places
print(123 + 345)
# Out:
# 468

# %%
# Large Integer
print(123_456_789)
# Out:
# 123456789

# %%
# Float: Numbers with decimal places or Floating point number
print(3.14159)
print(3141.59)
# Out:
# 3.14159
# 3141.59

# %%
# Boolean: True or False
print(True)
print(False)
# Out:
# True
# False

# %% [markdown]
# ## **Type Error, Type Checking and Type Conversion**

# %%
print(len(12345))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(len(12345))
#
# TypeError: object of type 'int' has no len()

# %%
print(len("12345"))
# Out:
# 5

# %% [markdown]
# - How would we know what data type a particular piece of data has?

# %%
print(type("Hello"))
# Out:
# <class 'str'>

# %%
print(type(123))
# Out:
# <class 'int'>

# %%
print(type("abc"))
print(type(123))
print(type(3.14))
print(type(True))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# - Now what if we aren't happy with the assigned data type?
# - What if we want to convert a piece of data into a different data type?
# - solution: type conversion or type casting

# %%
print("123" + "456")
# Out:
# 123456

# %%
print(int("123") + int("456"))
# Out:
# 579

# %% [markdown]
# - Sometimes you can't convert things into a different data type

# %%
print(int("abc") + int("456"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 print(int("abc") + int("456"))
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
# make the below code work
# print("Number of letters in your name: " + len(input("Enter your name")))

print("Number of letters in your name: " + str(len(input("Enter your name"))))
# Out:
# Enter your name Ananth
# Number of letters in your name: 6

# %% [markdown]
# ## **Mathematical Operations in Python**

# %%
print("My age: " + str(12))
print(123 + 456)
# Out:
# My age: 12
# 579

# %%
print(7 - 3)
print(3 * 2)
# Out:
# 4
# 6

# %%
print(6 / 3)
# Out:
# 2.0

# %%
print(type(6 / 3))
# Out:
# <class 'float'>

# %%
print(6 // 3)
print(type(6 // 3))
# Out:
# 2
# <class 'int'>

# %%
print(5 / 3)
print(type(5 // 3))
# Out:
# 1.6666666666666667
# <class 'int'>

# %%
print(2 ** 2)
print(2 ** 3)
# Out:
# 4
# 8

# %% [markdown]
# ### **Operator Precedence**
# - PEMDAS: Paranthesis, Exponents, Multiplication, Division, Addition and Subtraction

# %%
print(3 * 3 + 3 / 3 - 3)
# Out:
# 7.0

# %%
# Change the code so it outputs 3
print(3 * (3 + 3) / 3 - 3)
# Out:
# 3.0

# %% [markdown]
# ## **Number Manipulation and F Strings in Python**

# %%
bmi = 84 / 1.65 ** 2
print(bmi)
# Out:
# 30.85399449035813

# %% [markdown]
# - How would be able to round it to the nearest whole number or to a specified number of digits?

# %%
print(int(bmi))
# Out:
# 30

# %%
print(round(bmi))
# Out:
# 31

# %%
print(round(3.3))
print(round(3.5))
print(round(3.9))
# Out:
# 3
# 4
# 4

# %%
# round(number, ndigits)
print(round(bmi, 2))
# Out:
# 30.85

# %%
# assignment operator

score = 0

score += 1

print(score)
# Out:
# 1

# %% [markdown]
# ### **f-strings**

# %%
print("Your score is " + str(score))
# Out:
# Your score is 1

# %%
score = 0
height = 1.0
is_winning = True

print(f"Your score is = {score}")
# Out:
# Your score is = 0

# %%
print(f"Your score is = {score}, your height is {height}. You are winning is {is_winning}")
# Out:
# Your score is = 0, your height is 1.0. You are winning is True

# %% [markdown]
# ## **Day02: Tip Calculator**

# %%
print("Welcome to the tip calculator!")
bill = float(input("What was the total bill? $"))
tip  = int(input("what percentage tip would you like to give? 10, 12 or 15? "))
people = int(input("How many people to split the bill? "))

# bill_with_tip = tip / 100 * bill + bill
# bill_with_tip = bill * (1 + tip / 100)

tip_as_percent = tip / 100
total_tip_amount = bill * tip_as_percent
total_bill = bill + total_tip_amount
bill_per_person = total_bill / people
final_amount = round(bill_per_person, 2)
print(f"Each person should pay: ${final_amount}")
# Out:
# Welcome to the tip calculator!
# What was the total bill? $ 153.45
# what percentage tip would you like to give? 10, 12 or 15?  15
# How many people to split the bill?  5
# Each person should pay: $35.29
