# %% [markdown]
# ## **Printing to the console in Python**

# %% [markdown]
# - Why we are learning to program?
# - To be able to tell the computer what it needs to do, and for it to follow our commands

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# - Strings:
# - It's a string of characters and double quotes represents the beginning and end of that string of characters

# %%
print("Hello world!)
# Out:
#   Cell In[2], line 1
#     print("Hello world!)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# - But as with all things with AI, if we don't know what we're doing in the first place, these hints don't help us that much
# - For example, If I put the closing quote right after the paranthesis, I've got other problems and I'm going to create more problems for myself
# - So it's important that we first understand how things work and then use technology and AI to help us, such as in this case, to fix our bug
# - PEP8:
# - A good standard practice for how to write python code

# %% [markdown]
# ## **String Manipulation and Code Intelligence**

# %%
print("Hello world!")
print("Hello world!")
print("Hello world!")
# Out:
# Hello world!
# Hello world!
# Hello world!

# %%
print("Hello world!\nHello world!")
# Out:
# Hello world!
# Hello world!

# %%
print("Hello world!\nHello world!\nHello world!")
# Out:
# Hello world!
# Hello world!
# Hello world!

# %% [markdown]
# ### **Concatenation**
# - Combine different strings so that they will be added to the end of another string

# %%
print("Hello" + "Ananth")
# Out:
# HelloAnanth

# %%
print("Hello " + "Ananth")
print("Hello" + " Ananth")
print("Hello" + " " + "Ananth")
# Out:
# Hello Ananth
# Hello Ananth
# Hello Ananth

# %% [markdown]
# - Note:
# - In python programming spaces are really, really important
# - The spaces that you add in your code

# %%
print("Hello " + "Ananth")
print("Hello" + " Ananth")
    print("Hello" + " " + "Ananth")
# Out:
#   Cell In[9], line 3
#     print("Hello" + " " + "Ananth")
#     ^
# IndentationError: unexpected indent

# %%
print("Hello " + "Ananth")
print("Hello" + " Ananth")
print("Hello" + " " + "Ananth")
# Out:
# Hello Ananth
# Hello Ananth
# Hello Ananth

# %% [markdown]
# ## **The Python Input Function**

# %%
print("What is your name?")
# Out:
# What is your name?

# %%
input("What is your name?")
# Out:
# What is your name? Ananth
# 'Ananth'

# %%
print("Hello " + input("What is your name?"))
# Out:
# What is your name? Ananth
# Hello Ananth

# %%
print("Hello " + input("What is your name?") + "!")
# Out:
# What is your name? Ananth
# Hello Ananth!

# %% [markdown]
# - Note:
# - Use `thonny.org` and download an application to debug the python code or understand the flow of execution

# %% [markdown]
# ### **Commenting**
# - It is a line of text or python statement to not be considered by the computer at all
# - Something that the computer will completely ignore

# %%
# This line of code will take an input using the input() function
print("Hello " + input("What is your name?") + "!")
# Out:
# What is your name? Ananth
# Hello Ananth!

# %% [markdown]
# - Whenever we come across a new concept, to make a comment above it
# - So, that you can explain to yourself what's actually going on in the line of code below

# %% [markdown]
# ## **Python Variables**

# %%
input("What is your name?")
# Out:
# What is your name? Ananth
# 'Ananth'

# %%
name = input("What is your name?")
print(name)
# Out:
# What is your name? Ananth
# Ananth

# %%
name = "Jack"
print(name)

name = "Ananth"
print(name)
# Out:
# Jack
# Ananth

# %%
username = input("What is your name?")
length = len(username) 
print(length)
# Out:
# What is your name? Ananth
# 6

# %% [markdown]
# - len() function:
# - It finds the number of elements of collection data type

# %% [markdown]
# ## **Variable naming**

# %%
n = input("What is your name?")
l = len(n) 
print(l)
# Out:
# What is your name? Ananth
# 6

# %% [markdown]
# ```
# Rules:
#
# - Make sure your variable names are descriptive
# - Don't have spaces between words
# - Don't start with numbers
# - Don't use special words like print or input
# - Choose simple words that are less likely to become typos
# - Check the company style guidelines if you start work at a company
# ```

# %%
username = input("What is your name?")
length = len(username) 
print(length)
# Out:
# What is your name? Ananth
# 6

# %% [markdown]
# # **Day01: Band Name Generator**

# %% [markdown]
# ```
# Description:
#
# 1. Create a greeting for your program.
# 2. Ask the user for the city that they grew up in and store it in a variable.
# 3. Ask the user for the name of a pet and store it in a variable.
# 4. Combine the name of their city and pet and show them their band name.
# 5. Make sure the input cursor shows on a new line
# ```

# %%
print("Welcome to the Band Name Generator.")
city = input("Which city did you grow up in?\n")
pet = input("What is the name of pet?\n")
print("Your band name could be: " + city + " " + pet)
# Out:
# Welcome to the Band Name Generator.
# Which city did you grow up in?
#  Bristol
# What is the name of pet?
#  Rabbit
# Your band name could be: Bristol Rabbit
